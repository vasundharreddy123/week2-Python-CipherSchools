# %%
#Class1_Functions_CipherSchools

# %%
def show_loading():
  for _ in range(3):
    print("loading", "."*(i+1))

# %%
a = 5
b = 7
 print(a + b)
 show_loading()



 print(a - b)
 show_loading()


 print(a * b)
 show_loading()

# %%
x = 6
x = 'Vasundhar reddy'
x = 1.5
x = print

# %%
def sheldon_knock():

knock knock knock knock
knock knock knock knock
knock knock knock knock

# %%
def sheldon(name, times = 3):
  for _ in range(times):
    print("knock knock knock", name)

# %%
def add(a, b):
  return a + b

# %%
sheldon_knock("penny", 100)
